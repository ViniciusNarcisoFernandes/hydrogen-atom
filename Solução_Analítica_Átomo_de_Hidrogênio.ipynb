# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusNarcisoFernandes/hydrogen-atom/blob/main/Solu%C3%A7%C3%A3o_Anal%C3%ADtica_%C3%81tomo_de_Hidrog%C3%AAnio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Gráfico para R10
import numpy as np
import matplotlib.pyplot as plt

# Massa do elétron (kg):
m_e = 9.10938*10**(-31)

# Carga elétrica ([C]^2):
e = 1.60218*10**(-19)

# Permissividade do vácuo ([C]^(2).[eV]^(-1).[A]^(-1)):
eps0 = 1.4186*10**(-40)

# hcortado([ev].[s]):
hbar = 6.58209*10**(-16)

# Raio de Bohr:
a0 = (4*np.pi*eps0*np.power(hbar,2))*(16.0218)/(m_e*np.power(e,2))

# Raio:
r = np.linspace(0.0,50,10000)

# Solução analítica:
R10 = (2/np.power(a0,3/2))*np.exp(-r/a0)

# Plot:
plt.figure(figsize = (10,5))
plt.plot(r,R10,color='Black',linestyle='-.')
plt.title('Solução Analítica: $R_{10}$(r)')
plt.xlabel('r/a0')
plt.ylabel('$R_{10}$(r)')
plt.grid(True)
plt.show()

# %%
# Gráfico para R20
import numpy as np
import matplotlib.pyplot as plt

# Massa do elétron (kg):
m_e = 9.10938*10**(-31)

# Carga elétrica ([C]^2):
e = 1.60218*10**(-19)

# Permissividade do vácuo ([C]^(2).[eV]^(-1).[A]^(-1)):
eps0 = 1.4186*10**(-40)

# hcortado([ev].[s]):
hbar = 6.58209*10**(-16)

# Raio de Bohr:
a0 = (4*np.pi*eps0*np.power(hbar,2))*(16.0218)/(m_e*np.power(e,2))

# Raio:
r = np.linspace(0.0,50,10000)

# Solução analítica:
R20 = (1-r/(2*a0))/(np.sqrt(2)*np.power(a0,3/2))*np.exp(-r/2*a0)

# Plot:
plt.figure(figsize=(10,5))
plt.plot(r,R20,color='Red',linestyle='-.')
plt.title('Solução Analítica: $R_{20}$(r)')
plt.xlabel('r/a0')
plt.ylabel('$R_{20}$(r)')
plt.grid(True)
plt.show()

# %%
# Gráfico para R21
import numpy as np
import matplotlib.pyplot as plt

# Massa do elétron (kg):
m_e = 9.10938*10**(-31)

# Carga elétrica ([C]^2):
e = 1.60218*10**(-19)

# Permissividade do vácuo ([C]^(2).[eV]^(-1).[A]^(-1)):
eps0 = 1.4186*10**(-40)

# hcortado([ev].[s]):
hbar = 6.58209*10**(-16)

# Raio de Bohr:
a0 = (4*np.pi*eps0*np.power(hbar,2))*(16.0218)/(m_e*np.power(e,2))

# Raio:
r = np.linspace(0.0,50,10000)

# Solução analítica:
R21 = (r*np.exp(-r/2*a0))/(a0*np.sqrt(24)*np.power(a0,3/2))

# Plot:
plt.figure(figsize=(10,5))
plt.plot(r,R21,color='Red',linestyle='-.')
plt.title('Solução Analítica: $R_{21}$(r)')
plt.xlabel('r/a0')
plt.ylabel('$R_{21}$(r)')
plt.grid(True)
plt.show()

# %%
# Gráfico para R30
import numpy as np
import matplotlib.pyplot as plt

# Massa do elétron (kg):
m_e = 9.10938*10**(-31)

# Carga elétrica ([C]^2):
e = 1.60218*10**(-19)

# Permissividade do vácuo ([C]^(2).[eV]^(-1).[A]^(-1)):
eps0 = 1.4186*10**(-40)

# hcortado([ev].[s]):
hbar = 6.58209*10**(-16)

# Raio de Bohr:
a0 = (4*np.pi*eps0*np.power(hbar,2))*(16.0218)/(m_e*np.power(e,2))

# Raio:
r = np.linspace(0.0,50,10000)

# Solução analítica:
R30 = (2*np.exp(-r/3*a0))/(np.sqrt(27)*np.power(a0,(3/2)))*(1 - (2*r/3*a0) + (2*np.power(r,2)/27*np.power(a0,2)))

# Plot:
plt.figure(figsize=(10,5))
plt.plot(r,R30,color='Green',linestyle='-.')
plt.title('Solução Analítica: $R_{30}$(r)')
plt.xlabel('r/a0')
plt.ylabel('$R_{30}$(r)')
plt.grid(True)
plt.show()

# %%
# Gráfico para R31
import numpy as np
import matplotlib.pyplot as plt

# Massa do elétron (kg):
m_e = 9.10938*10**(-31)

# Carga elétrica ([C]^2):
e = 1.60218*10**(-19)

# Permissividade do vácuo ([C]^(2).[eV]^(-1).[A]^(-1)):
eps0 = 1.4186*10**(-40)

# hcortado([ev].[s]):
hbar = 6.58209*10**(-16)

# Raio de Bohr:
a0 = (4*np.pi*eps0*np.power(hbar,2))*(16.0218)/(m_e*np.power(e,2))

# Raio:
r = np.linspace(0.0,50,10000)

# Solução analítica:
R31 = 8*r*np.exp(-r/3*a0)/(27*np.sqrt(6)*np.power(a0,(3/2))*a0)*(1-(r/6*a0))

# Plot:
plt.figure(figsize=(10,5))
plt.plot(r,R31,color='Green',linestyle='-.')
plt.title('Solução Analítica: $R_{31}$(r)')
plt.xlabel('r/a0')
plt.ylabel('$R_{31}$(r)')
plt.grid(True)
plt.show()

# %%
# Gráfico para R32
import numpy as np
import matplotlib.pyplot as plt

# Massa do elétron (kg):
m_e = 9.10938*10**(-31)

# Carga elétrica ([C]^2):
e = 1.60218*10**(-19)

# Permissividade do vácuo ([C]^(2).[eV]^(-1).[A]^(-1)):
eps0 = 1.4186*10**(-40)

# hcortado([ev].[s]):
hbar = 6.58209*10**(-16)

# Raio de Bohr:
a0 = (4*np.pi*eps0*np.power(hbar,2))*(16.0218)/(m_e*np.power(e,2))

# Raio:
r = np.linspace(0.0,50,10000)

# Solução analítica:
R32 = ((4*np.exp(-r/3*a0)/(81*np.sqrt(30)*np.power(a0,3/2))))*(np.power(r/a0,2))

# Plot:
plt.figure(figsize=(10,5))
plt.plot(r,R32,color='Green',linestyle='-.')
plt.title('Solução Analítica: $R_{32}$(r)')
plt.xlabel('r/a0')
plt.ylabel('$R_{32}$(r)')
plt.grid(True)
plt.show()
